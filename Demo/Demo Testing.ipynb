# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

print("Libraries installed successfully!")
# Out:
# Libraries installed successfully!

# %%
arr = np.array([1,2,3])
arr*2
# Out:
# array([2, 4, 6])

# %%
data = {
    "Name":["kumar","Dhinesh","striver"],
    "Age":[20,19,27]
}
data
# Out:
# {'Name': ['kumar', 'Dhinesh', 'striver'], 'Age': [20, 19, 27]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    kumar   20
# 1  Dhinesh   19
# 2  striver   27

# %%
x = [1,2,3,4]
y = [10,20,30,40]

plt.plot(x,y)
plt.title("Simple Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
X = np.array([[1], [2], [3], [4]])
Y = np.array([2, 4, 6, 8])

model = LinearRegression()
model.fit(X,Y)
print("Prediction for 10: ",model.predict([[10]]))
# Out:
# Prediction for 10:  [20.]
